# /kaggle/input/clahe-hemm/clahe/train/no/521.png
# /kaggle/input/clahe-hemm/clahe/train/no/11.png
# /kaggle/input/clahe-hemm/clahe/train/no/615.png
# /kaggle/input/clahe-hemm/clahe/train/no/416.png
# /kaggle/input/clahe-hemm/clahe/train/no/605.png
# /kaggle/input/clahe-hemm/clahe/train/no/707.png
# /kaggle/input/clahe-hemm/clahe/train/no/351.png
# /kaggle/input/clahe-hemm/clahe/train/no/213.png
# /kaggle/input/clahe-hemm/clahe/train/no/411.png
# /kaggle/input/clahe-hemm/clahe/train/no/505.png
# /kaggle/input/clahe-hemm/clahe/train/no/114.png
# /kaggle/input/clahe-hemm/clahe/train/no/302.png
# /kaggle/input/clahe-hemm/clahe/train/no/185.png
# /kaggle/input/clahe-hemm/clahe/train/no/240.png
# ...
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/527.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/71.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/648.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/595.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/573.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/74.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/653.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/525.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/120.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/630.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/271.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/363.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/310.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/323.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/118.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/670.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/393.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/17.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/53.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/266.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/486.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/657.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/196.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/626.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/571.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/179.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/178.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/160.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/671.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/140.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/620.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/636.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/736.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/52.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/5.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/139.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/3.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/172.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/64.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/406.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/719.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/347.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/665.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/355.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/16.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/438.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/430.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/545.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/409.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/725.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/328.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/423.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/643.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/461.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/375.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/760.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/203.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/8.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/489.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/45.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/382.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/24.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/548.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/444.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/373.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/32.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/88.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/463.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/649.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/624.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/283.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/274.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/115.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/749.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/249.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/128.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/668.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/158.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/583.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/710.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/6.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/23.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/87.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/686.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/275.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/51.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/703.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/728.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/591.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/400.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/101.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/606.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/618.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/536.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/717.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/297.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/135.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/482.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/740.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/512.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/123.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/91.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/504.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/230.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/738.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/478.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/44.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/399.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/189.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/541.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/601.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/442.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/343.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/454.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/730.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/410.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/68.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/422.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/286.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/180.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/46.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/508.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/499.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/711.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/664.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/516.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/470.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/57.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/448.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/84.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/475.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/564.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/687.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/15.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/210.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/234.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/358.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/365.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/652.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/252.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/531.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/507.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/704.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/565.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/679.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/523.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/183.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/678.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/450.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/30.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/485.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/408.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/631.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/708.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/569.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/427.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/619.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/622.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/537.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/429.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/321.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/60.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/235.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/99.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/155.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/765.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/593.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/676.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/228.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/27.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/390.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/237.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/451.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/692.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/474.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/292.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/421.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/201.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/539.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/519.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/295.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/394.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/273.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/269.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/459.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/413.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/78.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/212.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/47.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/207.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/149.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/487.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/13.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/535.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/260.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/253.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/206.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/557.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/613.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/600.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/381.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/342.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/346.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/134.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/721.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/694.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/590.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/566.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/259.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/25.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/285.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/341.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/54.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/462.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/558.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/111.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/611.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/62.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/205.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/699.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/369.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/750.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/0.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/141.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/693.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/532.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/309.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/560.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/19.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/110.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/544.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/308.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/26.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/568.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/388.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/79.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/633.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/729.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/257.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/305.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/477.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/42.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/175.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/518.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/226.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/428.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/217.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/494.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/659.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/418.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/452.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/306.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/497.png
# /kaggle/input/histogram-equalized-bh/hist_ew/train/yes/304.png

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tqdm import tqdm

import os
import cv2
import shutil
import itertools

import tensorflow as tf
import keras_preprocessing
from keras_preprocessing import image
from keras.models import Model, Sequential
from keras.layers import Conv2D, Flatten, Dense, Dropout, MaxPooling2D
from tensorflow.keras.optimizers import Adam, RMSprop
from keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from keras_preprocessing.image import ImageDataGenerator

from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import cohen_kappa_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import confusion_matrix

#init_notebook_mode(connected=True)
RANDOM_SEED = 42

# %%
# train_dir = "../input/histogram-equalized-bh/hist_ew/train/"
# validation_dir = "../input/histogram-equalized-bh/hist_ew/validation/"
# test_dir = "../input/histogram-equalized-bh/hist_ew/test/"

#clahe

train_dir = "../input/clahe-hemm/clahe/train/"
validation_dir = "../input/clahe-hemm/clahe/validation/"
test_dir = "../input/clahe-hemm/clahe/test/"

# %%
def load_data(dir_path):
    X = []
    y = []
    i = 0
    labels = dict()
    for path in tqdm(sorted(os.listdir(dir_path))):
        if not path.startswith('.'):
            labels[i] = path
            for file in os.listdir(dir_path + path):
                if not file.startswith('.'):
                    img = cv2.imread(dir_path + path + '/' + file)
                    X.append(img)
                    y.append(i)
            i += 1
    X = np.array(X)
    y = np.array(y)
    print(f'{len(X)} images loaded from {dir_path} directory.')
    return X, y, labels

# %%
X_train, y_train, labels = load_data(train_dir)
X_test, y_test, _ = load_data(test_dir)
X_val, y_val, _ = load_data(validation_dir)
# Out:
# 100%|██████████| 2/2 [00:09<00:00,  4.60s/it]
# 1536 images loaded from ../input/clahe-hemm/clahe/train/ directory.
# 100%|██████████| 2/2 [00:02<00:00,  1.39s/it]
# 480 images loaded from ../input/clahe-hemm/clahe/test/ directory.
# 100%|██████████| 2/2 [00:02<00:00,  1.10s/it]
# 384 images loaded from ../input/clahe-hemm/clahe/validation/ directory.

# %%
X_train = np.array([cv2.resize(image, (224, 224)) for image in X_train])
X_test = np.array([cv2.resize(image, (224, 224)) for image in X_test])
X_val = np.array([cv2.resize(image, (224, 224)) for image in X_val])

print(X_train.shape)
print(X_test.shape)
print(X_val.shape)
# Out:
# (1536, 224, 224, 3)
# (480, 224, 224, 3)
# (384, 224, 224, 3)

# %%
# X_train = np.expand_dims(X_tr, axis=-1) 
# X_test = np.expand_dims(X_te, axis=-1)
# X_val = np.expand_dims(X_vl, axis=-1)

# X_train=X_train.reshape((1536, 224, 224, 1))
# X_test=X_test.reshape((480, 224, 224,1))
# X_val=X_val.reshape((384, 224, 224,1))

# print(X_train.shape)
# print(X_test.shape)
# print(X_val.shape)

# %%
# X_train=X_train.astype("float32")
# X_test=X_test.astype("float32")
# X_val=X_val.astype("float32")

# %%
input_shape = (224,224, 3)
batch_size = 32

# %%
training_datagen = ImageDataGenerator(rescale = 1./255)
validation_datagen = ImageDataGenerator(rescale = 1./255)

# %%
train_generator = training_datagen.flow_from_directory(
    train_dir,
    target_size=(224,224),
    batch_size=32,
    class_mode='binary',
    seed=RANDOM_SEED
)

val_generator = validation_datagen.flow_from_directory(
    validation_dir,
    target_size=(224,224),
    batch_size=32,
    class_mode='binary',
    seed=RANDOM_SEED
)
# Out:
# Found 1536 images belonging to 2 classes.
# Found 384 images belonging to 2 classes.

# %%
model = tf.keras.Sequential([
    
    tf.keras.layers.Conv2D(32,(3,3),activation='relu',input_shape=(224,224,3)),
    tf.keras.layers.MaxPooling2D(2,2),
    
    tf.keras.layers.Conv2D(32,(3,3),activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    
    tf.keras.layers.Conv2D(64,(3,3),activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    
    tf.keras.layers.Conv2D(64,(3,3),activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    
    tf.keras.layers.Conv2D(128,(3,3),activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dropout(0.40),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.40),
    tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.Dropout(0.40),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_20 (Conv2D)           (None, 222, 222, 32)      896
# _________________________________________________________________
# max_pooling2d_20 (MaxPooling (None, 111, 111, 32)      0
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 109, 109, 32)      9248
# _________________________________________________________________
# max_pooling2d_21 (MaxPooling (None, 54, 54, 32)        0
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 52, 52, 64)        18496
# _________________________________________________________________
# max_pooling2d_22 (MaxPooling (None, 26, 26, 64)        0
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 24, 24, 64)        36928
# _________________________________________________________________
# max_pooling2d_23 (MaxPooling (None, 12, 12, 64)        0
# _________________________________________________________________
# conv2d_24 (Conv2D)           (None, 10, 10, 128)       73856
# _________________________________________________________________
# max_pooling2d_24 (MaxPooling (None, 5, 5, 128)         0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 3200)              0
# _________________________________________________________________
# dense_16 (Dense)             (None, 64)                204864
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_17 (Dense)             (None, 128)               8320
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_18 (Dense)             (None, 256)               33024
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_19 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 385,889
# Trainable params: 385,889
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(
    loss='binary_crossentropy',
    optimizer= RMSprop(learning_rate=1e-4),
    metrics=['accuracy']
)

# %%
EPOCHS = 100
reduce_lr = ReduceLROnPlateau(
    monitor='val_accuracy',
    factor=0.1,
    patience=3,
    min_lr=1e-6,
    verbose=1)

es = EarlyStopping(
    monitor='val_accuracy', 
    mode='max',
    patience=6
)
filename = 'clahe_data_model_1.h5'
check_pt = ModelCheckpoint(
    filename,
    monitor="val_accuracy",
    verbose=1,
    save_best_only=True
)

history = model.fit(train_generator, epochs=EPOCHS, batch_size=16, validation_data=val_generator, callbacks=[reduce_lr, es, check_pt])
# Out:
# Epoch 1/100
# 48/48 [==============================] - 7s 134ms/step - loss: 0.6930 - accuracy: 0.5052 - val_loss: 0.6897 - val_accuracy: 0.5000
#
# Epoch 00001: val_accuracy improved from -inf to 0.50000, saving model to clahe_data_model_1.h5
# Epoch 2/100
# 48/48 [==============================] - 5s 112ms/step - loss: 0.6890 - accuracy: 0.5384 - val_loss: 0.6812 - val_accuracy: 0.5469
#
# Epoch 00002: val_accuracy improved from 0.50000 to 0.54688, saving model to clahe_data_model_1.h5
# Epoch 3/100
# 48/48 [==============================] - 6s 120ms/step - loss: 0.6816 - accuracy: 0.5775 - val_loss: 0.6551 - val_accuracy: 0.6693
#
# Epoch 00003: val_accuracy improved from 0.54688 to 0.66927, saving model to clahe_data_model_1.h5
# Epoch 4/100
# 48/48 [==============================] - 6s 123ms/step - loss: 0.6524 - accuracy: 0.6224 - val_loss: 0.6028 - val_accuracy: 0.7344
#
# Epoch 00004: val_accuracy improved from 0.66927 to 0.73438, saving model to clahe_data_model_1.h5
# Epoch 5/100
# 48/48 [==============================] - 6s 120ms/step - loss: 0.6019 - accuracy: 0.6940 - val_loss: 0.5405 - val_accuracy: 0.7630
#
# Epoch 00005: val_accuracy improved from 0.73438 to 0.76302, saving model to clahe_data_model_1.h5
# Epoch 6/100
# 48/48 [==============================] - 6s 116ms/step - loss: 0.5642 - accuracy: 0.7227 - val_loss: 0.5272 - val_accuracy: 0.7552
#
# Epoch 00006: val_accuracy did not improve from 0.76302
# Epoch 7/100
# 48/48 [==============================] - 6s 129ms/step - loss: 0.5475 - accuracy: 0.7324 - val_loss: 0.5404 - val_accuracy: 0.7109
#
# Epoch 00007: val_accuracy did not improve from 0.76302
# Epoch 8/100
# 48/48 [==============================] - 6s 118ms/step - loss: 0.5221 - accuracy: 0.7676 - val_loss: 0.4916 - val_accuracy: 0.7812
#
# Epoch 00008: val_accuracy improved from 0.76302 to 0.78125, saving model to clahe_data_model_1.h5
# Epoch 9/100
# 48/48 [==============================] - 6s 116ms/step - loss: 0.4952 - accuracy: 0.7865 - val_loss: 0.4653 - val_accuracy: 0.7969
#
# Epoch 00009: val_accuracy improved from 0.78125 to 0.79688, saving model to clahe_data_model_1.h5
# Epoch 10/100
# 48/48 [==============================] - 5s 112ms/step - loss: 0.4806 - accuracy: 0.7826 - val_loss: 0.4463 - val_accuracy: 0.8047
#
# Epoch 00010: val_accuracy improved from 0.79688 to 0.80469, saving model to clahe_data_model_1.h5
# Epoch 11/100
# 48/48 [==============================] - 6s 117ms/step - loss: 0.4539 - accuracy: 0.7995 - val_loss: 0.4245 - val_accuracy: 0.8151
#
# Epoch 00011: val_accuracy improved from 0.80469 to 0.81510, saving model to clahe_data_model_1.h5
# Epoch 12/100
# 48/48 [==============================] - 6s 124ms/step - loss: 0.4398 - accuracy: 0.8073 - val_loss: 0.4127 - val_accuracy: 0.8203
#
# Epoch 00012: val_accuracy improved from 0.81510 to 0.82031, saving model to clahe_data_model_1.h5
# Epoch 13/100
# 48/48 [==============================] - 6s 124ms/step - loss: 0.4411 - accuracy: 0.8145 - val_loss: 0.4069 - val_accuracy: 0.8177
#
# Epoch 00013: val_accuracy did not improve from 0.82031
# Epoch 14/100
# 48/48 [==============================] - 6s 118ms/step - loss: 0.4121 - accuracy: 0.8359 - val_loss: 0.4412 - val_accuracy: 0.8125
#
# Epoch 00014: val_accuracy did not improve from 0.82031
# Epoch 15/100
# 48/48 [==============================] - 6s 120ms/step - loss: 0.3927 - accuracy: 0.8392 - val_loss: 0.3776 - val_accuracy: 0.8229
#
# Epoch 00015: val_accuracy improved from 0.82031 to 0.82292, saving model to clahe_data_model_1.h5
# Epoch 16/100
# 48/48 [==============================] - 6s 122ms/step - loss: 0.3865 - accuracy: 0.8457 - val_loss: 0.3793 - val_accuracy: 0.8307
#
# Epoch 00016: val_accuracy improved from 0.82292 to 0.83073, saving model to clahe_data_model_1.h5
# Epoch 17/100
# 48/48 [==============================] - 6s 122ms/step - loss: 0.3643 - accuracy: 0.8529 - val_loss: 0.3688 - val_accuracy: 0.8333
#
# Epoch 00017: val_accuracy improved from 0.83073 to 0.83333, saving model to clahe_data_model_1.h5
# Epoch 18/100
# 48/48 [==============================] - 5s 111ms/step - loss: 0.3513 - accuracy: 0.8607 - val_loss: 0.3428 - val_accuracy: 0.8646
#
# Epoch 00018: val_accuracy improved from 0.83333 to 0.86458, saving model to clahe_data_model_1.h5
# Epoch 19/100
# 48/48 [==============================] - 6s 116ms/step - loss: 0.3191 - accuracy: 0.8698 - val_loss: 0.3360 - val_accuracy: 0.8646
#
# Epoch 00019: val_accuracy did not improve from 0.86458
# Epoch 20/100
# 48/48 [==============================] - 5s 111ms/step - loss: 0.3189 - accuracy: 0.8691 - val_loss: 0.3620 - val_accuracy: 0.8411
#
# Epoch 00020: val_accuracy did not improve from 0.86458
# Epoch 21/100
# 48/48 [==============================] - 5s 114ms/step - loss: 0.3117 - accuracy: 0.8757 - val_loss: 0.3307 - val_accuracy: 0.8620
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
#
# Epoch 00021: val_accuracy did not improve from 0.86458
# Epoch 22/100
# 48/48 [==============================] - 5s 113ms/step - loss: 0.2730 - accuracy: 0.8867 - val_loss: 0.3092 - val_accuracy: 0.8646
#
# Epoch 00022: val_accuracy did not improve from 0.86458
# Epoch 23/100
# 48/48 [==============================] - 6s 125ms/step - loss: 0.2614 - accuracy: 0.9010 - val_loss: 0.3101 - val_accuracy: 0.8672
#
# Epoch 00023: val_accuracy improved from 0.86458 to 0.86719, saving model to clahe_data_model_1.h5
# Epoch 24/100
# 48/48 [==============================] - 5s 113ms/step - loss: 0.2564 - accuracy: 0.8965 - val_loss: 0.3134 - val_accuracy: 0.8724
#
# Epoch 00024: val_accuracy improved from 0.86719 to 0.87240, saving model to clahe_data_model_1.h5
# Epoch 25/100
# 48/48 [==============================] - 6s 117ms/step - loss: 0.2578 - accuracy: 0.9004 - val_loss: 0.3074 - val_accuracy: 0.8672
#
# Epoch 00025: val_accuracy did not improve from 0.87240
# Epoch 26/100
# 48/48 [==============================] - 5s 113ms/step - loss: 0.2480 - accuracy: 0.9049 - val_loss: 0.3072 - val_accuracy: 0.8672
#
# Epoch 00026: val_accuracy did not improve from 0.87240
# Epoch 27/100
# 48/48 [==============================] - 6s 115ms/step - loss: 0.2389 - accuracy: 0.9095 - val_loss: 0.3064 - val_accuracy: 0.8672
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 1e-06.
#
# Epoch 00027: val_accuracy did not improve from 0.87240
# Epoch 28/100
# 48/48 [==============================] - 5s 110ms/step - loss: 0.2429 - accuracy: 0.9043 - val_loss: 0.3062 - val_accuracy: 0.8672
#
# Epoch 00028: val_accuracy did not improve from 0.87240
# Epoch 29/100
# 48/48 [==============================] - 5s 111ms/step - loss: 0.2427 - accuracy: 0.9056 - val_loss: 0.3062 - val_accuracy: 0.8672
#
# Epoch 00029: val_accuracy did not improve from 0.87240
# Epoch 30/100
# 48/48 [==============================] - 5s 113ms/step - loss: 0.2362 - accuracy: 0.9128 - val_loss: 0.3060 - val_accuracy: 0.8672
#
# Epoch 00030: val_accuracy did not improve from 0.87240

# %%
epochs_range = range(1, len(history.epoch) + 1)
plt.figure(figsize=(15,5))

plt.subplot(1, 2, 1)
plt.plot(epochs_range, history.history["accuracy"], label=' Train Set')
plt.plot(epochs_range, history.history["val_accuracy"], label='Val Set')
plt.plot( 36, 0.95052, marker="x", color="g", label="best model")
plt.xlabel('Epochs')
plt.ylabel("Accuracy")
plt.legend(loc="best")
plt.title('Model Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, history.history["loss"], label=' Train Set')
plt.plot(epochs_range, history.history["val_loss"], label='Val Set')
plt.xlabel('Epochs')
plt.ylabel("Loss")
plt.legend(loc="best")
plt.title('Model Loss')

plt.tight_layout()
plt.show()

# %%
from tensorflow.keras.models import load_model
saved_model = load_model('./clahe_data_model_1.h5')

# %%
from sklearn.metrics import roc_curve

# validate on test set
predictions = model.predict(X_val)
predictions = [1 if x>0.5 else 0 for x in predictions]

_, train_acc = model.evaluate(X_train, y_train, verbose=0)
_, val_acc = model.evaluate(X_val, y_val, verbose=0)

print('Train: %.4f, Val: %.4f' % (train_acc, val_acc))

accuracy = accuracy_score(y_val, predictions)
print('Validation Accuracy = %.4f' % accuracy)

# precision: tp / (tp + fp)
precision = precision_score(y_val, predictions)
print('Precision: %f' % precision)

  # recall: tp / (tp + fn)
recall = recall_score(y_val, predictions)
print('Recall: %f' % recall)

  # f1: 2 tp / (2 tp + fp + fn)
f1 = f1_score(y_val, predictions)
print('F1 score: %f' % f1)

#KAPPA SCORE
kappa = cohen_kappa_score(y_val, predictions)
print('Cohens kappa: %f' % kappa)

  # ROC AUC
auc = roc_auc_score(y_val, predictions)
print('ROC AUC: %f' % auc)
 
# confusion matrix
matrix = confusion_matrix(y_val, predictions)
print(matrix)

tn, fp, fn, tp = matrix.ravel()
print("True positive:", tp, ", True negative:", tn,
            ", False positive:", fp, ", False negative:", fn)

sensitivity = tp / (tp + fn)
specificity = tn / (tn + fp)

print("Sensitivity: {:.4f}".format(sensitivity))
print("Specificity: {:.4f}".format(specificity))

fpr, tpr, thresholds = roc_curve(y_val, predictions)

fig, ax = plt.subplots()
ax.plot(fpr, tpr)
ax.plot([0, 1], [0, 1], transform=ax.transAxes, ls="--", c=".3")
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.rcParams['font.size'] = 12
plt.title('ROC curve')
plt.xlabel('False Positive Rate (1 - Specificity)')
plt.ylabel('True Positive Rate (Sensitivity)')
plt.grid(True)
# Out:
# Train: 0.9154, Val: 0.8672
# Validation Accuracy = 0.8672
# Precision: 0.861538
# Recall: 0.875000
# F1 score: 0.868217
# Cohens kappa: 0.734375
# ROC AUC: 0.867188
# [[165  27]
#  [ 24 168]]
# True positive: 168 , True negative: 165 , False positive: 27 , False negative: 24
# Sensitivity: 0.8750
# Specificity: 0.8594

# %%
# validate on test set (saved model)
predictions = model.predict(X_test)
predictions = [1 if x>0.5 else 0 for x in predictions]

_, train_acc = model.evaluate(X_train, y_train, verbose=0)
_, test_acc = model.evaluate(X_test, y_test, verbose=0)

print('Train: %.4f, Test: %.4f' % (train_acc, test_acc))

accuracy = accuracy_score(y_test, predictions)
print('Test Accuracy = %.4f' % accuracy)

# precision: tp / (tp + fp)
precision = precision_score(y_test, predictions)
print('Precision: %f' % precision)

  # recall: tp / (tp + fn)
recall = recall_score(y_test, predictions)
print('Recall: %f' % recall)

  # f1: 2 tp / (2 tp + fp + fn)
f1 = f1_score(y_test, predictions)
print('F1 score: %f' % f1)

#KAPPA SCORE
kappa = cohen_kappa_score(y_test, predictions)
print('Cohens kappa: %f' % kappa)

  # ROC AUC
auc = roc_auc_score(y_test, predictions)
print('ROC AUC: %f' % auc)
 
# confusion matrix
matrix = confusion_matrix(y_test, predictions)
print(matrix)

tn, fp, fn, tp = matrix.ravel()
print("True positive:", tp, ", True negative:", tn,
            ", False positive:", fp, ", False negative:", fn)


sensitivity = tp / (tp + fn)
specificity = tn / (tn + fp)

print("Sensitivity: {:.4f}".format(sensitivity))
print("Specificity: {:.4f}".format(specificity))

fpr, tpr, thresholds = roc_curve(y_test, predictions)

fig, ax = plt.subplots()
ax.plot(fpr, tpr)
ax.plot([0, 1], [0, 1], transform=ax.transAxes, ls="--", c=".3")
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.rcParams['font.size'] = 12
plt.title('ROC curve')
plt.xlabel('False Positive Rate (1 - Specificity)')
plt.ylabel('True Positive Rate (Sensitivity)')
plt.grid(True)
# Out:
# Train: 0.9154, Test: 0.8667
# Test Accuracy = 0.8667
# Precision: 0.876068
# Recall: 0.854167
# F1 score: 0.864979
# Cohens kappa: 0.733333
# ROC AUC: 0.866667
# [[211  29]
#  [ 35 205]]
# True positive: 205 , True negative: 211 , False positive: 29 , False negative: 35
# Sensitivity: 0.8542
# Specificity: 0.8792

# %%
predicted = model.predict(X_test)
predicted = [1 if x>0.5 else 0 for x in predicted]
#print_images=True
#if print_images:
rows = 8
col = 8
j = 0
fig = plt.figure(figsize=(30, 25))

for i in range(len(predicted)):
    if predicted[i] != y_test[i]:
        j = j + 1
        fig.add_subplot(rows, col, j)
        plt.imshow(X_test[i])
        plt.axis('off')
        plt.title("pred "+str(predicted[i])+" actual "+str(y_test[i]))
